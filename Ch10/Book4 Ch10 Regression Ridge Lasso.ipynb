# %% [markdown]
# #Book4 Ch10 10-6-1 to 10-6-2

# %% [markdown]
# # 10-6-1

# %% [markdown]
# # 연속변수 타겟일 경우 회귀(Linear Regression) 모델

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Book4/Ch10/Bike_distance1.xlsx')
df.shape
# Out:
# (8755, 52)

# %%
data = df.drop(['Rented Bike Count'], axis=1)   # 타깃 변수를 제외한 변수만 data에 저장
target = df['Rented Bike Count']                # 타깃 변수만 target에 저장

# %%
# 50:50 data partition.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.5, random_state=42)   # test_size=0.5임에 주의

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (4377, 51)
# X_test shape: (4378, 51)

# %%
# 연속변수 타겟변수일 때 Linear Regression 모델 (Default 모델)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

linr = LinearRegression(n_jobs=-1)
model = linr.fit(X_train, y_train)
pred = model.predict(X_test)

print ("Linear Regression Training set r2 score:{:.5f}".format(model.score(X_train, y_train)))
print ("Linear Regression Test set r2 score:{:.5f}".format(r2_score(y_test, pred)))
# Out:
# Linear Regression Training set r2 score:0.71791
# Linear Regression Test set r2 score:0.70845

# %% [markdown]
# # 10-6-2

# %% [markdown]
# # 연속변수 타겟일 경우 릿지(Ridge) 및 라쏘(Lasso) 모델

# %%
# 연속변수 타겟변수일 때 Ridge 모델 (Default 모델)
from sklearn.linear_model import Ridge
Ridge = Ridge(random_state=42)
model = Ridge.fit(X_train, y_train)
pred = model.predict(X_test)

print ("Linear Regression Training set score:{:.5f}".format(model.score(X_train, y_train)))
print ("Linear Regression Test set score:{:.5f}".format(r2_score(y_test, pred)))
# Out:
# Linear Regression Training set score:0.71786
# Linear Regression Test set score:0.70865

# %%
# 연속변수 타겟변수일 때 Lasso 모델 (Default 모델)
from sklearn.linear_model import Lasso
Lasso = Lasso(random_state=42)
model = Lasso.fit(X_train, y_train)
pred = model.predict(X_test)

print ("Linear Regression Training set score:{:.5f}".format(model.score(X_train, y_train)))
print ("Linear Regression Test set score:{:.5f}".format(r2_score(y_test, pred)))
# Out:
# Linear Regression Training set score:0.71521
# Linear Regression Test set score:0.70606

# %%
# 책의 그리드 서치 결과를 대입한 Ridge 모델
from sklearn.linear_model import Ridge
Ridge = Ridge(random_state=42, alpha=0.1, solver='saga')
model = Ridge.fit(X_train, y_train)
pred = model.predict(X_test)

print ("Linear Regression Training set score:{:.5f}".format(model.score(X_train, y_train)))
print ("Linear Regression Test set score:{:.5f}".format(r2_score(y_test, pred)))
# Out:
# Linear Regression Training set score:0.71792
# Linear Regression Test set score:0.70852

# %%
# 책의 그리드 서치 결과를 대입한 Lasso 모델
from sklearn.linear_model import Lasso
Lasso = Lasso(random_state=42, alpha=0.1)
model = Lasso.fit(X_train, y_train)
pred = model.predict(X_test)

print ("Linear Regression Training set score:{:.5f}".format(model.score(X_train, y_train)))
print ("Linear Regression Test set score:{:.5f}".format(r2_score(y_test, pred)))
# Out:
# Linear Regression Training set score:0.71788
# Linear Regression Test set score:0.70856
